# %%
import numpy as np
import matplotlib.pyplot as plt

path = "C:/Users/schiavaz/lava-nc/depth/"
dataset = "data/stripes/"

# %%
events = np.loadtxt(path + dataset + "events.txt")

# %%
events.shape
# Out:
# (340394, 4)

# %%
events = events[100000:200000]

# %%
xl = 50
xh = 70
yl = 90
yh = 110

# %%
events = events[np.logical_and(events[:, 1] > xl, events[:, 1] < xh)]

# %%
events = events[np.logical_and(events[:, 2] > yl, events[:, 2] < yh)]

# %%
events
# Out:
# array([[  0.309124,  61.      ,  96.      ,   1.      ],
#        [  0.309126,  61.      ,  99.      ,   1.      ],
#        [  0.309203,  61.      , 101.      ,   1.      ],
#        ...,
#        [  0.646203,  60.      ,  91.      ,   1.      ],
#        [  0.64622 ,  56.      ,  99.      ,   1.      ],
#        [  0.646958,  51.      ,  93.      ,   1.      ]])

# %%
events.shape
# Out:
# (2486, 4)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(events[:, 0], events[:, 1], events[:, 2])

ax.set_xlabel("time", fontsize=16)
ax.set_ylabel("x", fontsize=16)
ax.set_zlabel("y", fontsize=16)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'y')

# %%
t = np.load("cam_ts00011.npy")

# %%
t.shape
# Out:
# (480, 640)

# %%
plt.imshow(t)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30340/772836229.py in <module>
# ----> 1 plt.imshow(t)
#
# c:\users\schiavaz\lava-nc\venv\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\users\schiavaz\lava-nc\venv\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2638         interpolation_stage=None, filternorm=True, filterrad=4.0,
# ...
