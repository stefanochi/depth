# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display

# %%
with open('data_s.npy', 'rb') as f:
    data_s = np.load(f, allow_pickle=True).tolist()["Process_6"]["s_out"]

# %%
with open('data_t.npy', 'rb') as f:
    data_t = np.load(f, allow_pickle=True).tolist()["Process_6"]["trig"]

# %%
with open('data_u.npy', 'rb') as f:
    data_u = np.load(f, allow_pickle=True).tolist()["Process_6"]["u"]

# %%
with open('data_s_s.npy', 'rb') as f:
    data_s_s = np.load(f, allow_pickle=True).tolist()["Process_1"]["s_out"]

# %%
#plt.plot(data_u[:, 17, 65])
plt.plot(data_s[:,43, 16])

# %%
plt.figure(figsize=(10, 10))
m = plt.imshow(np.sum(data_s, axis=0))
plt.colorbar(mappable=m)

# %%
test = np.sum(data_s, axis=0)

# %%
np.argmax(test)
# Out:
# 3413

# %%
np.unravel_index(np.argmax(test), test.shape)
# Out:
# (43, 16)

# %%
# %matplotlib notebook
fig = plt.figure()

im = plt.imshow(data_s_s[0,:,:], animated=True)
im.set_clim(vmin=0, vmax=1)

def updatefig(i):
    im.set_array(data_s_s[i,:,:])
    return im,

anim = FuncAnimation(fig, updatefig, frames=100, blit=True, interval=100)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_394/2547887346.py in <module>
#       2 fig = plt.figure()
#       3
# ----> 4 im = plt.imshow(data_s_s[0,:,:], animated=True)
#       5 im.set_clim(vmin=0, vmax=1)
#       6
#
# NameError: name 'data_s_s' is not defined

# %%
# %matplotlib inline
plt.imshow(data_s_s[22,:,:])

# %%
with open('data_cd1_a.npy', 'rb') as f:
    data_cd1_a = np.load(f, allow_pickle=True).tolist()["Process_7"]["a_out"]
with open('data_cd2_a.npy', 'rb') as f:
    data_cd2_a = np.load(f, allow_pickle=True).tolist()["Process_8"]["a_out"]

# %%
# %matplotlib inline
plt.imshow(data_cd1_a[50, :, :])

# %%
plt.imshow(data_cd2_a[50, :, :] + data_cd1_a[50, :, :])
