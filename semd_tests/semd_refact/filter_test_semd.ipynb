# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append("../../")

import numpy as np
from matplotlib import pyplot as plt

from lava.proc.io.source import RingBuffer
from lava.proc.io.sink import RingBuffer as SinkBuffer

from lava.magma.core.run_configs import RunConfig, Loihi1SimCfg
from lava.magma.core.run_conditions import RunSteps

from semd.proc.semd.process import SemdLayer

from utils import get_events_range

# %%
events = np.loadtxt("../../data_processed/events_refact.txt")
# this data is already filtered by time, no need to redo it here

# %%
def filter_patch(events, patch_center, patch_size):
    x_lim = (patch_center[1] - int(patch_size / 2), patch_center[1] + int(patch_size / 2) - 1)
    y_lim = (patch_center[0] - int(patch_size / 2), patch_center[0] + int(patch_size / 2) - 1)

    events_filtered = np.copy(events)
    events_filtered = events_filtered[
        np.logical_and((x_lim[0] <= events_filtered[:, 1]), (events_filtered[:, 1] <= x_lim[1]))]
    events_filtered = events_filtered[
        np.logical_and((y_lim[0] <= events_filtered[:, 2]), (events_filtered[:, 2] <= y_lim[1]))]
    # events_filtered = events_filtered[[(y_lim[0] >= events_range[:,2]) & (events_range[:,2] <= y_lim[1])]
    #vents_filtered = np.array(events_filtered)

    events_filtered[:,1] = (events_filtered[:,1] - patch_center[1] + int(patch_size / 2)).astype(int)
    events_filtered[:,2] = (events_filtered[:,2] - patch_center[0] + int(patch_size / 2)).astype(int)
    
    return events_filtered

# %%
def gen_input_data(events, shape, timesteps):
    result = np.zeros((shape[0], shape[1], timesteps), dtype=int)
    for e in events:
        x = int(e[1])
        y = int(e[2])

        time = int((float(e[0]) - t_start) / duration * timesteps) - 1

        if e[3] == 1:
            continue

        result[y, x, time] = 1
    return result

# %%
def run_sim(args, events):
    shape = args["shape"]
    conv_stride = args["conv_stride"]
    conv_shape = args["conv_shape"]
    
#     out_shape = (int(shape[0] / conv_stride[0]), int(shape[1] / conv_stride[1]))
#     detector_shape = (out_shape[0], out_shape[1] - 1)
    
    semd = SemdLayer(**args)
    
    out_shape = semd.out_shape
    detector_shape = semd.detector_shape

    input_data = gen_input_data(events, shape, timesteps)
    input_n = RingBuffer(input_data)

    output_n = SinkBuffer(shape=detector_shape, buffer=steps)

    input_n.s_out.connect(semd.s_in)
    semd.s_out.connect(output_n.a_in)

    rcfg = Loihi1SimCfg(select_tag='floating_pt', select_sub_proc_model=True)

    for i in range(steps):
        run_condition = RunSteps(num_steps=1)
        input_n.run(condition=run_condition, run_cfg=rcfg)
    data = output_n.data.get()
    input_n.stop()
    
    return data

# %%
# use only the specified patch of input events
patch_center = (90, 120)
patch_size = 180
events = filter_patch(events, patch_center, patch_size)

timesteps = 100 # timesteps to divide the data into
steps = 100 # simulation steps
shape = (patch_size, patch_size)
t_start = events[0, 0]
duration = events[-1, 0] - events[0, 0]

# %%
args = {
    "shape":shape,
    "conv_shape": (3,3),
    "conv_stride": (3,3),
    "thresh_conv": 0.65
}
data = run_sim(args, events)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data, axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# 0.65
# 10
# (3, 3)
# 0.65
# [[[[1.70940171]
#    [1.70940171]
#    [1.70940171]]
#
#   [[1.70940171]
#    [1.70940171]
#    [1.70940171]]
#
#   [[1.70940171]
#    [1.70940171]
#    [1.70940171]]]]
# 1.7094017094017093

# %%
args = {
    "shape":shape,
    "conv_shape": (2,2),
    "conv_stride": (2,2),
    "thresh_conv": 0.5
}
data = run_sim(args, events)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data, axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# 0.5
# 10
# (2, 2)
# 0.5
# [[[[5.]
#    [5.]]
#
#   [[5.]
#    [5.]]]]
# 5.0

# %%
args = {
    "shape":shape,
    "conv_shape": (4,4),
    "conv_stride": (4,4),
    "thresh_conv": 0.5
}
data = run_sim(args, events)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data, axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# 0.5
# 10
# (4, 4)
# 0.5
# [[[[1.25]
#    [1.25]
#    [1.25]
#    [1.25]]
#
#   [[1.25]
#    [1.25]
#    [1.25]
#    [1.25]]
#
#   [[1.25]
#    [1.25]
#    [1.25]
#    [1.25]]
#
#   [[1.25]
#    [1.25]
#    [1.25]
#    [1.25]]]]
# 1.25

# %%
args = {
    "shape":shape,
    "conv_shape": (5,5),
    "conv_stride": (5,5),
    "thresh_conv": 0.6
}
data = run_sim(args, events)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data, axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# 0.6
# 10
# (5, 5)
# 0.6
# [[[[0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]]
#
#   [[0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]]
#
#   [[0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]]
#
#   [[0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]]
#
#   [[0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]
#    [0.66666667]]]]
# 0.6666666666666667

# %%
args = {
    "shape":shape,
    "conv_shape": (2,2),
    "conv_stride": (1,1),
    "thresh_conv": 0.5
}
data = run_sim(args, events)
# Out:
# 0.5
# 10
# (2, 2)
# 0.5
# [[[[5.]
#    [5.]]
#
#   [[5.]
#    [5.]]]]
# 5.0

# %%
plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data, axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)

# %%
args = {
    "shape":shape,
    "conv_shape": (1,1),
    "conv_stride": (1,1),
    "thresh_conv": 1
}
data = run_sim(args, events)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data, axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# ---------------------------------------------------------------------------
# NoProcessModelFound                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23128/730233.py in <module>
#       5     "thresh_conv": 1
#       6 }
# ----> 7 data = run_sim(args, events)
#       8
#       9 plt.figure(figsize=(10, 10))
#
# ~\AppData\Local\Temp/ipykernel_23128/437840654.py in run_sim(args, events)
#      24     for i in range(steps):
#      25         run_condition = RunSteps(num_steps=1)
# ---> 26         input_n.run(condition=run_condition, run_cfg=rcfg)
#      27     data = output_n.data.get()
#      28     input_n.stop()
#
# ~\lava-nc\lava\src\lava\magma\core\process\process.py in run(self, condition, run_cfg)
#     397
#     398         if not self._runtime:
# --> 399             executable = self.compile(run_cfg)
#     400             self._runtime = Runtime(executable,
#     401                                     ActorType.MultiProcessing)
#
# ~\lava-nc\lava\src\lava\magma\core\process\process.py in compile(self, run_cfg)
#     346         from lava.magma.compiler.compiler import Compiler
#     347         compiler = Compiler()
# --> 348         return compiler.compile(self, run_cfg)
#     349
#     350     def save(self, path: str):
#
# ~\lava-nc\lava\src\lava\magma\compiler\compiler.py in compile(self, proc, run_cfg)
#     993             p._is_compiled = True
#     994
# --> 995         proc_map = self._map_proc_to_model(procs, run_cfg)
#     996         # ToDo: Still need to register ProcModel somehow with Proc so
#     997         #  interactive access is possible later
#
# ~\lava-nc\lava\src\lava\magma\compiler\compiler.py in _map_proc_to_model(self, procs, run_cfg)
#     263         for p in procs:
#     264             # Select a specific ProcessModel
# --> 265             models_cls = self._find_proc_models(p)
#     266             model_cls = self._select_proc_models(p, models_cls, run_cfg)
#     267             if issubclass(model_cls, AbstractSubProcessModel):
#
# ~\lava-nc\lava\src\lava\magma\compiler\compiler.py in _find_proc_models(self, proc)
#     186
#     187         if not proc_models:
# --> 188             raise ex.NoProcessModelFound(proc)
#     189         return proc_models
#     190
#
# NoProcessModelFound: No ProcessModels found that implement Process '<semd.proc.semd.process.SemdLayer object at 0x0000018025F18CA0>'

# %%
events_unfiltered = np.loadtxt("../../data/events.txt")
t_start = 2.6
duration = 0.1
events_unfiltered = get_events_range(events_unfiltered, t_start, duration)

# use only the specified patch of input events
patch_center = (90, 120)
patch_size = 180
events_unfiltered = filter_patch(events_unfiltered, patch_center, patch_size)

timesteps = 50 # timesteps to divide the data into
steps = 50 # simulation steps
shape = (patch_size, patch_size)

args = {
    "shape":shape,
    "conv_shape": (2,2),
    "conv_stride": (2,2),
    "thresh_conv": 0.5
}
data = run_sim(args, events_unfiltered)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data[:,:,:], axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# 0.5
# 10
# (2, 2)
# 0.5
# [[[[5.]
#    [5.]]
#
#   [[5.]
#    [5.]]]]
# 5.0

# %%
plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data[:,:,:20], axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)

# %%
args = {
    "shape":shape,
    "conv_shape": (2,2),
    "conv_stride": (1,1),
    "thresh_conv": 0.5
}
data = run_sim(args, events_unfiltered)

plt.figure(figsize=(10, 10))
m = plt.imshow(np.delete(np.sum(data[:,:,:], axis=-1), 0, 1), cmap="jet")
plt.colorbar(m)
# Out:
# 0.5
# 10
# (2, 2)
# 0.5
# [[[[5.]
#    [5.]]
#
#   [[5.]
#    [5.]]]]
# 5.0
